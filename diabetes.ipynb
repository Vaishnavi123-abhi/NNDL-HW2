# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi123-abhi/NNDL-HW2/blob/main/diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
path_to_csv = ('/content/gdrive/My Drive/diabetes.csv')

# %%
import keras
import pandas
from keras.models import Sequential
from keras.layers.core import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv('/content/gdrive/MyDrive/NN&DeepLearning_ICP2_Summer_SourceCode/NN&DeepLearning_Lesson7_SourceCode/diabetes.csv', header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 5s 3ms/step - loss: 15.5896 - acc: 0.3333
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 7.8785 - acc: 0.4635
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.5462 - acc: 0.5642
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.4812 - acc: 0.6128
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.1716 - acc: 0.6059
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.9916 - acc: 0.5903
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.8894 - acc: 0.6024
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.8194 - acc: 0.6181
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.7059 - acc: 0.6181
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.6132 - acc: 0.6198
# Epoch 11/100
# ...

# %%
b = Sequential() # create model
b.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
b.add(Dense(10, input_dim=8, activation='relu'))
b.add(Dense(5, input_dim=8, activation='relu'))
b.add(Dense(1, activation='sigmoid')) # output layer
b.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
b_fitted = b.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(b.summary())
print(b.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 2s 6ms/step - loss: 3.8590 - acc: 0.5208
# Epoch 2/100
# 18/18 [==============================] - 0s 5ms/step - loss: 2.3947 - acc: 0.5747
# Epoch 3/100
# 18/18 [==============================] - 0s 6ms/step - loss: 2.0100 - acc: 0.5851
# Epoch 4/100
# 18/18 [==============================] - 0s 6ms/step - loss: 1.6978 - acc: 0.6042
# Epoch 5/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.4901 - acc: 0.6076
# Epoch 6/100
# 18/18 [==============================] - 0s 7ms/step - loss: 1.3717 - acc: 0.6302
# Epoch 7/100
# 18/18 [==============================] - 0s 6ms/step - loss: 1.2471 - acc: 0.6441
# Epoch 8/100
# 18/18 [==============================] - 0s 7ms/step - loss: 1.1433 - acc: 0.6510
# Epoch 9/100
# 18/18 [==============================] - 0s 8ms/step - loss: 1.0076 - acc: 0.6632
# Epoch 10/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9572 - acc: 0.6771
# Epoch 11/100
# ...
